# %%
# !python generate_data.py
# Out:
# Saved telecom_synthetic_dataset.csv
# operator
# Jio       50
# Airtel    28
# BSNL       4
# Name: count, dtype: int64
#
# Churn rate overall: 69.5%
# operator
# Airtel    0.607143
# BSNL      0.000000
# Jio       0.800000
# Name: churned, dtype: float64

# %%
# !python train_model.py
# Out:
# Numeric/binary features: ['download_speed_mbps', 'got_4g_instead_of_5g', 'post_expiry_calls_3x', 'signal_problems', 'sits_under_sunlight_for_network', 'phonepe_extra_charge', 'call_cut_zero_balance', 'no_1gb_per_day_plan', 'data_loan_available']
# Categorical features: ['operator', 'plan_type', 'years_using_sim', 'age_group']
#
# === Model Performance ===
# Accuracy: 0.95
#
# Confusion matrix:
# [[ 5  1]
#  [ 0 15]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#       Stayed       1.00      0.83      0.91         6
#      Churned       0.94      1.00      0.97        15
#
#     accuracy                           0.95        21
#    macro avg       0.97      0.92      0.94        21
# weighted avg       0.96      0.95      0.95        21
#
#
# === Top features pushing toward CHURN (positive coefficients) ===
#                         feature  coefficient
#            phonepe_extra_charge     2.881438
# ...
